# %%
# Melakukan Resize Image
# !python resize.py

# %%
# Melihat/menampilkan koordinat dari image
# !python facerecog1.py
# Out:
# Koordinat wajah:
# Top: 206
# Right: 491
# Bottom: 527
# Left: 170

# %%
# Hasil Uji dengan Diri Sendiri
# !python Uji_dengan_diri_sendiri.py
# Out:
# [True]

# %%
# Hasil Uji dengan Orang Lain
# !python Uji_dengan_orang_lain.py
# Out:
# [False]

# %%
# Deteksi wajah dan memisahkan hasil deteksi
# !python separateface.py

# %% [markdown]
# ### Melakukan uji coba deteksi wajah

# %%
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
from PIL import Image

# %%
# !python webcameye.py
# Out:
# ^C

# %%
img = Image.open('image/hasildeteksi1.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Melakukan uji coba deteksi wajah penyesuaian

# %%
# !python facerecog3.py
# Out:
# ^C

# %%
img = Image.open('image/hasildeteksi2.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Menampilkan perbandingan gambar diri sendiri dengan orang lain menggunakan gambar orang lain

# %%
# !python picklesave.py

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20,10))

image1 = Image.open('image/anggi-small.jpg')
ax[0].imshow(image1)
ax[0].set_title('Encode Image Anggi')

image2 = Image.open('image/kinan-small.jpg')
ax[1].imshow(image2)
ax[1].set_title('Encode Image Kinan')

image3 = Image.open('image/kinan-small.jpg')
ax[2].imshow(image3)
ax[2].set_title('Image Compare Kinan')

plt.show()

# %%
# !python pickleload-other.py
# Out:
# [('Anggi', True), ('Kinan', True)]

# %% [markdown]
# ### Menampilkan perbandingan gambar diri sendiri dengan orang lain menggunakan gambar diri sendiri

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20,10))

image1 = Image.open('image/anggi-small.jpg')
ax[0].imshow(image1)
ax[0].set_title('Encode Image Anggi')

image2 = Image.open('image/kinan-small.jpg')
ax[1].imshow(image2)
ax[1].set_title('Encode Image Kinan')

image3 = Image.open('image/anggi-small.jpg')
ax[2].imshow(image3)
ax[2].set_title('Image Compare Anggi')

plt.show()

# %%
# !python pickleload-selff.py
# Out:
# [('Anggi', True), ('Kinan', True)]

# %% [markdown]
# ### Menampilkan hasil ujicoba selanjutnya

# %%
import cv2

# %%
# !python facerecog4.py
# Out:
# ^C

# %%
img = Image.open('image/hasildeteksi3.png')
plt.imshow(img)
plt.show()
